# %%
import pandas as pd

# %% [markdown]
# 1. Cread una columna nueva y una función que nos de el mes donde ocurrió el ataque. Tened en cuenta que no todas las filas tienen la misma estructura y que puede que no haya la información de mes. En ese caso devolved un nulo (NaN).
#
# 💡 Pista 💡Podéis usar regex.

# %%
df = pd.read_csv('../DATA/Ejercicio_Pandas_5.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1672 non-null   int64
#  1   Case Number             1672 non-null   object
#  2   Year                    1672 non-null   float64
#  3   Type                    1672 non-null   object
#  4   Country                 1662 non-null   object
#  5   Area                    1626 non-null   object
#  6   Location                1621 non-null   object
#  7   Activity                1641 non-null   object
#  8   Name                    1663 non-null   object
#  9   Sex                     1658 non-null   object
#  10  Age                     1518 non-null   object
#  11  Time                    1512 non-null   object
#  12  Species                 1546 non-null   object
#  13  Investigator Or Source  169 non-null    object
#  14  Pdf                     170 non-null    object
#  15  Href Formula            170 non-null    object
#  16  Href                    1672 non-null   object
#  17  Case Number.1           170 non-null    object
#  18  Case Number.2           1672 non-null   object
#  19  Original Order          170 non-null    float64
#  20  Unnamed: 22             0 non-null      float64
#  21  Unnamed: 23             0 non-null      float64
#  22  Siglo                   1502 non-null   object
#  23  Fatal (Y/N)             1585 non-null   object
#  24  Injury                  1664 non-null   object
#  25  Date                    1672 non-null   object
# dtypes: float64(4), int64(1), object(21)
# memory usage: 339.8+ KB

# %%
df.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type    Country        Area  \
# 0           0    2018.06.25  2018.0     Boating        USA  California
# 1           1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2           2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3           3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4           4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        Location        Activity                    Name Sex   \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#    ...                                               Href Case Number.1  \
# 0  ...  http://sharkattackfile.net/spreadsheets/pdf_di...           NaN
# 1  ...  http://sharkattackfile.net/spreadsheets/pdf_di...           NaN
# 2  ...  http://sharkattackfile.net/spreadsheets/pdf_di...           NaN
# 3  ...  http://sharkattackfile.net/spreadsheets/pdf_di...           NaN
# 4  ...  http://sharkattackfile.net/spreadsheets/pdf_di...           NaN
#
#   Case Number.2 Original Order Unnamed: 22 Unnamed: 23      Siglo Fatal (Y/N)  \
# 0    2018.06.25            NaN         NaN         NaN  siglo_XXI           N
# 1  2018.06.03.a            NaN         NaN         NaN  siglo_XXI           Y
# 2  2018.05.26.b            NaN         NaN         NaN  siglo_XXI           N
# 3    2018.05.24            NaN         NaN         NaN  siglo_XXI           N
# 4  2018.05.13.a            NaN         NaN         NaN  siglo_XXI           N
#
#                                               Injury         Date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                                              FATAL  03-Jun-2018
# 2                              Lower left leg bitten  26-May-2018
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018
#
# [5 rows x 26 columns]

# %%
df['Case Number'][0]
# Out:
# '2018.06.25'

# %%
df['Case Number'][0].split('.')
# Out:
# ['2018', '06', '25']

# %%
df['Case Number'][0].split('.')[1]
# Out:
# '06'

# %%
from cmath import nan


def sacar_mes(fecha):
    try:
        return fecha.split('.')[1]
    except:
        return nan

# %%
df['Mes'] = df['Case Number'].apply(sacar_mes)

# %%
df.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type    Country        Area  \
# 0           0    2018.06.25  2018.0     Boating        USA  California
# 1           1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2           2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3           3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4           4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        Location        Activity                    Name Sex   \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#    ... Case Number.1 Case Number.2 Original Order Unnamed: 22 Unnamed: 23  \
# 0  ...           NaN    2018.06.25            NaN         NaN         NaN
# 1  ...           NaN  2018.06.03.a            NaN         NaN         NaN
# 2  ...           NaN  2018.05.26.b            NaN         NaN         NaN
# 3  ...           NaN    2018.05.24            NaN         NaN         NaN
# 4  ...           NaN  2018.05.13.a            NaN         NaN         NaN
#
#        Siglo Fatal (Y/N)                                             Injury  \
# 0  siglo_XXI           N  No injury to occupant, outrigger canoe and pad...
# 1  siglo_XXI           Y                                              FATAL
# 2  siglo_XXI           N                              Lower left leg bitten
# 3  siglo_XXI           N  Minor bite to hand by captive shark. PROVOKED ...
# 4  siglo_XXI           N  Injured by teeth of a dead porbeagle shark he ...
#
#           Date  Mes
# 0  25-Jun-2018   06
# 1  03-Jun-2018   06
# 2  26-May-2018   05
# 3  24-May-2018   05
# 4  13-May-2018   05
#
# [5 rows x 27 columns]

# %%
df['Mes'].unique()  ## !!!! hacer regex
# Out:
# array(['06', '05', '04', '03', '02', '01', '12', '11', '10', '09', '08',
#        '07', '07-10', '00', '0214', '0336', '0493', '0725', nan, '0110',
#        '0104', '0102', '0100', '0097', '0096', '0095', '0094', '0093',
#        '0091', '0090', '0089', '0088', '0087', '0086', '0085', '0084',
#        '0083', '0082', '0081', '0078', '0076', '0075', '0074', '0073',
#        '0069', '0068', '0066', '0065', '0064', '0063', '0062', '0060',
#        '0059', '0058', '0057', '0056', '0055', '0054', '0053', '0052',
#        '0051', '0049', '0048', '0047', '0046', '0044', '0043', '0042',
#        '0041', '0040', '0039', '0038', '0037', '0036', '0035', '0034',
#        '0033', '0032', '0031', '0030', '0028', '0027', '0026', '0025',
#        '0024', '0023', '0022', '0021', '0020', '0019', '0018', '0017',
#        '0016', '0015', '0014', '0013', '0012', '0011', '0010', '0009',
#        '0008', '0007', '0006', '0005', '0004', '0003', '0002', '0001'],
#       dtype=object)

# %%
def sacar_mes(x):
    try:
        c = x.split("-")[1].strip()
        # ponerle filtro de regex para que se quede con los meses sin año en 4 casos contados
        # o filtrar por la len de la palabra y eliminar los 4 casos excepcionales de mesaño
        return 
    except:
         return nan

df['Mes'] = df['Date'].apply(sacar_mes)

# %% [markdown]
# 2. Vamos con la columna fatal_(y/n). Lo primero que tenéis que hacer es evaluar los valores únicos que hay. Esperaríamos tener solo dos valores: y y n, pero tristemente no debería ser así 😭. Cread una columna nueva y una función que devuelva únicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %%
df['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'M', '2017', ' N', 'UNKNOWN'], dtype=object)

# %%
def limpia_fatal (fatal):
    if fatal == 'N':
        return 'N'
    elif fatal == 'Y':
        return 'Y'
    else:
        return nan

# %%
df['Fatal_limpio'] = df['Fatal (Y/N)'].apply(limpia_fatal)

# %%
df.tail()
# Out:
#       Unnamed: 0 Case Number  Year        Type             Country  \
# 1667        1667     ND.0005   0.0  Unprovoked           AUSTRALIA
# 1668        1668     ND.0004   0.0  Unprovoked           AUSTRALIA
# 1669        1669     ND.0003   0.0  Unprovoked                 USA
# 1670        1670     ND.0002   0.0  Unprovoked              PANAMA
# 1671        1671     ND.0001   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 1667  Western Australia                          Roebuck Bay        Diving
# 1668  Western Australia                                  NaN  Pearl diving
# 1669     North Carolina                       Ocracoke Inlet      Swimming
# 1670                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 1671   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ... Case Number.2 Original Order  \
# 1667                   male    M  ...       ND.0005            6.0
# 1668                  Ahmun    M  ...       ND.0004            5.0
# 1669  Coast Guard personnel    M  ...       ND.0003            4.0
# 1670        Jules Patterson    M  ...       ND.0002            3.0
# 1671                   male    M  ...       ND.0001            2.0
#
#      Unnamed: 22 Unnamed: 23 Siglo Fatal (Y/N)  \
# 1667         NaN         NaN   NaN           Y
# 1668         NaN         NaN   NaN           Y
# 1669         NaN         NaN   NaN           Y
# 1670         NaN         NaN   NaN           Y
# 1671         NaN         NaN   NaN           Y
#
#                                                  Injury         Date   Mes  \
# 1667                                              FATAL  Before 1903  0005
# 1668                                              FATAL  Before 1903  0004
# 1669                                              FATAL    1900-1905  0003
# 1670                                              FATAL    1883-1889  0002
# 1671  FATAL. "Shark bit him in half, carrying away t...    1845-1853  0001
#
#       Fatal_limpio
# 1667             Y
# 1668             Y
# 1669             Y
# 1670             Y
# 1671             Y
#
# [5 rows x 28 columns]

# %%
df['Fatal_limpio'].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %% [markdown]
# 3. Seguid la misma lógica que en el ejercicio anterior pero con la columna sex. Pero en este caso vamos a incluir un retito más: En este caso querremos tener dos valores únicos F y M. De nuevo en la columna hay otros carácteres raros como 'M ', 'lli', 'N', '.'. En esos casos, queremos que se reemplacen por M o F de forma aleatoria (tendréis que usar la librería random). En caso de que sea nulo, que la función devuelva nulo (np.nan).

# %%
import numpy as np # utilizaremos el metodo np.random.choice() para la asignacion random de valores

# %%
df['Sex '].unique()
# Out:
# array(['F', 'M', 'lli', nan], dtype=object)

# %%
def unificar_sexo (sex):
    lista = ['F','M']
    if sex == 'F':
        return 'F'
    elif sex == 'M':
        return 'M'
    elif sex == 'lli':
        np.random.choice(lista)
    else:
        nan

# %%
df['Sex (M/F)'] = df['Sex '].apply(unificar_sexo)

# %%
df.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type    Country        Area  \
# 0           0    2018.06.25  2018.0     Boating        USA  California
# 1           1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2           2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3           3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4           4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        Location        Activity                    Name Sex   \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#    ... Original Order Unnamed: 22 Unnamed: 23      Siglo Fatal (Y/N)  \
# 0  ...            NaN         NaN         NaN  siglo_XXI           N
# 1  ...            NaN         NaN         NaN  siglo_XXI           Y
# 2  ...            NaN         NaN         NaN  siglo_XXI           N
# 3  ...            NaN         NaN         NaN  siglo_XXI           N
# 4  ...            NaN         NaN         NaN  siglo_XXI           N
#
#                                               Injury         Date Mes  \
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018  06
# 1                                              FATAL  03-Jun-2018  06
# 2                              Lower left leg bitten  26-May-2018  05
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018  05
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018  05
#
#   Fatal_limpio  Sex (M/F)
# 0            N          F
# 1            Y          M
# 2            N          M
# 3            N          M
# 4            N          M
#
# [5 rows x 29 columns]

# %%
df['Sex (M/F)'].unique()
# Out:
# array(['F', 'M', None], dtype=object)
