# %% [markdown]
# EJERCICIO 1
# Id cargando todos los ficheros en vuestro jupyter.
# Si os da error leer el pickle será por la versión de pandas. Podéis guardar el csv como pickle y cargarlo de ahí.

# %%
import pandas as pd
import numpy as np
import pickle

# %%
csv=pd.read_csv("../DATA/quejas.csv",sep=";",encoding="ISO-8859-1")
json=pd.read_json("quejas.json")
excel=pd.read_excel("quejas2.xlsx")
pickle=pd.read_pickle("algas.pickle")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fk/9dj5qplx5dv2l_dlsz8sf1pw0000gn/T/ipykernel_47800/1230756641.py in <module>
#       1 csv=pd.read_csv("../DATA/quejas.csv",sep=";",encoding="ISO-8859-1")
# ----> 2 json=pd.read_json("quejas.json")
#       3 excel=pd.read_excel("quejas2.xlsx")
#       4 pickle=pd.read_pickle("algas.pickle")
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Expected object or value

# %%
csv.to_pickle('../DATA/quejas.pkl')

# %% [markdown]
# EJERCICIO 2
# Para poner el práctica el read_clipboard elegir alguna tabla que os podaís encontrar en google y usad dicho método para traer los datos al jupyter notebook. Una vez que los hayáis cargado, guardad esos datos en los siguientes formatos:
# csv
# excel
# json
# pickle

# %%
df_clipboard = pd.read_clipboard(sep = "\t")
df_clipboard.head(23)
#NO ME SALE EXACTAMENTE EN EL FORMATO (SHAPE) QUE QUIERO, PENDIENTE DE REVISAR
# Out:
#     Profesora                             Alumna  Módulo 1\nEquipo  \
# 0         NaN           Anais denise anna Bonamy                 1
# 1         NaN              María González Dueñas                 1
# 2         NaN           Natalia Martinez Catalan                 1
# 3         NaN               Yadira Gonzalez Lara                 1
# 4         NaN         Ángela Ariana Rosales Caro                 2
# 5         NaN                 Antoanela Mateciuc                 2
# 6         NaN                Chloe Aroca Mendoza                 2
# 7         NaN                        Lara Sancho                 2
# 8         NaN  Lucía García-Cernuda Ruiz de Alda                 2
# 9         NaN                   Ana Delia Torres                 3
# 10        NaN       Diana Laura Romero Feliciano                 3
# 11        NaN                Paula Collado Saura                 3
# 12        NaN        Verónica Bellido San Martín                 3
#
#     Módulo 2\nEquipo  Módulo 3\nEquipo  Módulo 1\nPareja 1 Módulo 1\nPareja 2  \
# 0                  1               NaN                   1                  2
# 1                  2               NaN                   2                  3
# 2                  2               NaN                   1                  1
# 3                  1               NaN                   3                  7
# 4                  3               NaN                   5                  1
# 5                  1               NaN                   7                  5
# 6                  3               NaN                   2                  2
# 7                  3               NaN                   5                  3
# 8                  1               NaN                   6                  7
# 9                  1               NaN                   6                  5
# 10                 2               NaN                   3                  6
# 11                 2               NaN                   7                4/2
# 12                 3               NaN                   4                  6
#
#     Módulo 2\nPareja 1  Módulo 2\nPareja 2  Módulo 3\nPareja 1  \
# 0                    1                 NaN                 NaN
# 1                    3                 NaN                 NaN
# 2                    4                 NaN                 NaN
# 3                    1                 NaN                 NaN
# 4                    5                 NaN                 NaN
# 5                    6                 NaN                 NaN
# 6                    6                 NaN                 NaN
# 7                    2                 NaN                 NaN
# 8                    3                 NaN                 NaN
# 9                    1                 NaN                 NaN
# 10                   2                 NaN                 NaN
# 11                   4                 NaN                 NaN
# 12                   5                 NaN                 NaN
#
#     Módulo 3\nPareja 2
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN

# %%
# guardaar el formato en csv

df_clipboard.to_csv("Equiposyparejas.csv")

# %%
# guardar en formato de excel

df_clipboard.to_excel("Equiposyparejas.xlsx")

# %%
# guardar en formato json

df_clipboard.to_json("Equiposyparejas.json")

# %%
# guardar en formato pickle

df_clipboard.to_pickle("Equiposyparejas.pickle")
