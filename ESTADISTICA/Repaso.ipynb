# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import skew
import scipy.stats as st

# %%
# df = pd.read_csv('Crime_data_2010_2017.csv', encoding='ISO-8859-1')

# %%
# def año (date=df['Date Occurred']):
#     return date.split('/')[2]

# %%
#df['Year'] = df['Date Occurred'].apply(año)

# %%
#df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting District  Crime Code                    Crime Code Description  \
# 0                1241         626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                          VEHICLE - STOLEN
# 2                1823         510                          VEHICLE - STOLEN
# 3                1803         510                          VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
#               MO Codes  ...  Status Code Status Description Crime Code 1  \
# 0  0416 0446 1243 2000  ...           AO        Adult Other        626.0
# 1                  NaN  ...           IC        Invest Cont        510.0
# 2                  NaN  ...           IC        Invest Cont        510.0
# 3                  NaN  ...           IC        Invest Cont        510.0
# 4                 0329  ...           IC        Invest Cont        745.0
#
#    Crime Code 2 Crime Code 3  Crime Code 4  \
# 0           NaN          NaN           NaN
# 1           NaN          NaN           NaN
# 2           NaN          NaN           NaN
# 3           NaN          NaN           NaN
# 4           NaN          NaN           NaN
#
#                                    Address Cross Street             Location   \
# 0  6300    BRYNHURST                    AV          NaN  (33.9829, -118.3338)
# 1                                 VAN NESS         15TH  (34.0454, -118.3157)
# 2   200 E  104TH                        ST          NaN   (33.942, -118.2717)
# 3                                     88TH         WALL  (33.9572, -118.2717)
# 4  7200    CIRRUS                       WY          NaN  (34.2009, -118.6369)
#
#    Year
# 0  2013
# 1  2010
# 2  2013
# 3  2010
# 4  2014
#
# [5 rows x 27 columns]

# %%
#pd.to_numeric(df.Year)
# Out:
# 0          2013
# 1          2010
# 2          2013
# 3          2010
# 4          2014
#            ...
# 1584311    2017
# 1584312    2017
# 1584313    2017
# 1584314    2017
# 1584315    2017
# Name: Year, Length: 1584316, dtype: int64

# %%
#df2 = df[df['Year']=='2017']

# %%
#df2.to_csv('Crime_Data_2017.csv')

# %%
df = pd.read_csv('Crime_Data_2017.csv')

# %%
# df.dropna(how='any', inplace=True)

# %%
# df.to_csv('Crime_Data_2017.csv')

# %%
df.drop([100000,151584],axis=0)
# Out:
#         Unnamed: 0  DR Number Date Reported Date Occurred  Time Occurred  \
# 0           659052  171013348    07/21/2017    07/20/2017           2000
# 1           736175  171013326    07/21/2017    07/21/2017           1000
# 2          1314361  170209449    04/22/2017    04/21/2017           1930
# 3          1388899  170206243    02/14/2017    02/11/2017           1700
# 4          1389475  170311599    04/25/2017    04/25/2017            745
# ...            ...        ...           ...           ...            ...
# 151580     1584310  172116479    09/07/2017    09/07/2017           1030
# 151581     1584311  172116482    09/07/2017    09/07/2017           1005
# 151582     1584312  172116489    09/07/2017    09/07/2017           1200
# 151583     1584313  172116491    08/30/2017    07/15/2017              1
# 151585     1584315  172116510    09/08/2017    07/12/2017           2230
#
#         Area ID    Area Name  Reporting District  Crime Code  \
# 0            10  West Valley                1047         330
# 1            10  West Valley                1008         330
# 2             2      Rampart                 201         510
# 3             2      Rampart                 275         510
# 4             3    Southwest                 325         510
# ...         ...          ...                 ...         ...
# 151580       21      Topanga                2189         310
# 151581       21      Topanga                2141         440
# 151582       21      Topanga                2156         330
# 151583       21      Topanga                2147         649
# 151585       21      Topanga                2105         236
#
#                        Crime Code Description  ... Premise Code  \
# 0                       BURGLARY FROM VEHICLE  ...          NaN
# 1                       BURGLARY FROM VEHICLE  ...          NaN
# 2                            VEHICLE - STOLEN  ...        101.0
# 3                            VEHICLE - STOLEN  ...        101.0
# 4                            VEHICLE - STOLEN  ...        101.0
# ...                                       ...  ...          ...
# 151580                               BURGLARY  ...        501.0
# 151581     THEFT PLAIN - PETTY ($950 & UNDER)  ...        501.0
# 151582                  BURGLARY FROM VEHICLE  ...        108.0
# 151583       DOCUMENT FORGERY / STOLEN FELONY  ...        203.0
# 151585  INTIMATE PARTNER - AGGRAVATED ASSAULT  ...        502.0
#
#                                  Premise Description Weapon Used Code  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                             STREET              NaN
# 3                                             STREET              NaN
# 4                                             STREET              NaN
# ...                                              ...              ...
# 151580                        SINGLE FAMILY DWELLING              NaN
# 151581                        SINGLE FAMILY DWELLING              NaN
# 151582                                   PARKING LOT              NaN
# 151583                                OTHER BUSINESS              NaN
# 151585  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)            400.0
#
#                                     Weapon Description  Status Code  \
# 0                                                  NaN           IC
# 1                                                  NaN           IC
# 2                                                  NaN           IC
# 3                                                  NaN           IC
# 4                                                  NaN           IC
# ...                                                ...          ...
# 151580                                             NaN           IC
# 151581                                             NaN           IC
# 151582                                             NaN           IC
# 151583                                             NaN           IC
# 151585  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)           IC
#
#        Status Description                                   Address  \
# 0             Invest Cont                                        00
# 1             Invest Cont                                        00
# 2             Invest Cont                                ALEXANDRIA
# 3             Invest Cont                                   OLYMPIC
# 4             Invest Cont                                   VERMONT
# ...                   ...                                       ...
# 151580        Invest Cont  20200    DELITA                       DR
# 151581        Invest Cont  23800    CALVERT                      ST
# 151582        Invest Cont   6600    TOPANGA CANYON               BL
# 151583        Invest Cont  20900    SHERMAN                      WY
# 151585        Invest Cont   8600    INTERNATIONAL                AV
#
#        Cross Street             Location   Year
# 0               NaN                   NaN  2017
# 1               NaN                   NaN  2017
# 2           ROMAINE  (34.0886, -118.2979)  2017
# 3          WESTLAKE  (34.0512, -118.2787)  2017
# 4             ADAMS  (34.0328, -118.2915)  2017
# ...             ...                   ...   ...
# 151580          NaN  (34.1641, -118.5742)  2017
# 151581          NaN  (34.1883, -118.6536)  2017
# 151582          NaN  (34.1905, -118.6059)  2017
# 151583          NaN   (34.201, -118.5885)  2017
# 151585          NaN  (34.2258, -118.5994)  2017
#
# [151584 rows x 24 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0      659052  171013348    07/21/2017    07/20/2017           2000       10
# 1      736175  171013326    07/21/2017    07/21/2017           1000       10
# 2     1314361  170209449    04/22/2017    04/21/2017           1930        2
# 3     1388899  170206243    02/14/2017    02/11/2017           1700        2
# 4     1389475  170311599    04/25/2017    04/25/2017            745        3
#
#      Area Name  Reporting District  Crime Code Crime Code Description  ...  \
# 0  West Valley                1047         330  BURGLARY FROM VEHICLE  ...
# 1  West Valley                1008         330  BURGLARY FROM VEHICLE  ...
# 2      Rampart                 201         510       VEHICLE - STOLEN  ...
# 3      Rampart                 275         510       VEHICLE - STOLEN  ...
# 4    Southwest                 325         510       VEHICLE - STOLEN  ...
#
#   Premise Code  Premise Description Weapon Used Code Weapon Description  \
# 0          NaN                  NaN              NaN                NaN
# 1          NaN                  NaN              NaN                NaN
# 2        101.0               STREET              NaN                NaN
# 3        101.0               STREET              NaN                NaN
# 4        101.0               STREET              NaN                NaN
#
#    Status Code Status Description     Address Cross Street  \
# 0           IC        Invest Cont          00          NaN
# 1           IC        Invest Cont          00          NaN
# 2           IC        Invest Cont  ALEXANDRIA      ROMAINE
# 3           IC        Invest Cont     OLYMPIC     WESTLAKE
# 4           IC        Invest Cont     VERMONT        ADAMS
#
#               Location   Year
# 0                   NaN  2017
# 1                   NaN  2017
# 2  (34.0886, -118.2979)  2017
# 3  (34.0512, -118.2787)  2017
# 4  (34.0328, -118.2915)  2017
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (151586, 28)

# %%
df.info()

# %%
df.describe()

# %%
df.describe(include=object)

# %%
df.isnull().sum()

# %%
df[df.duplicated()].count()

# %%
df.dropna(how='all',inplace=True)

# %%
df.isnull().sum()

# %%
df.drop(columns=['Crime Code 1', 'Crime Code 2', 'Crime Code 3', 'Crime Code 4'], inplace=True)

# %%
df.to_csv('Crime_Data_2017.csv')

# %% [markdown]
# Moda, mediana, media, mínimo y máximo

# %%
moda = df['Crime Code Description'].mode()
media = df['Victim Age'].mean()
mediana = df['Victim Age'].median()
minimo = df['Victim Age'].min()
maximo = df['Victim Age'].max()
print(moda, '----', media, '----', mediana, '----', minimo, '----', maximo)

# %% [markdown]
# Gráficos

# %%
plt.figure(figsize=(15,8))
sns.histplot(data = df, x = "Victim Age", color = "grey")
plt.axvline(media, color='red')
plt.axvline(mediana, color='orange');
